# %% [markdown]
# ## Python import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf

from keras import layers
from keras import models
from keras import Input
from keras.models import Model
from keras.models import Sequential
from keras import optimizers
from keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, Dropout
from keras.utils import to_categorical
from keras import regularizers # L2규제

from tensorflow.keras.preprocessing.image import ImageDataGenerator # data augmentation
from tensorflow.keras.callbacks import LearningRateScheduler # callbacks 설정

from tqdm.notebook import tqdm # 모델학습 진행 시간 파악
import random # random seed를 뽑을때 사용

# %% [markdown]
# #gpu사용
# config= tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth=True

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ## Load Data

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## EDA

# %%
idx = 45
img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
digit = train.loc[idx, 'digit']
letter = train.loc[idx, 'letter']

plt.title('Index: %i, Digit: %s, Letter: %s'%(idx, digit, letter))
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Train model

# %%
x_train = train.drop(['id', 'digit', 'letter'], axis=1).values
x_train = x_train.reshape(-1, 28, 28, 1)
x_train = x_train/255

y = train['digit']
y_train = np.zeros((len(y), len(y.unique())))
for i, digit in enumerate(y):
    y_train[i, digit] = 1

# %%
x_train1 = np.repeat(x_train, 3, axis=1)

# %%
x_train2 = np.repeat(x_train1, 3, axis=2)

# %%
def create_cnn_model():
    inputs = Input(shape = (84,84,1))
    
    bn = tf.keras.layers.BatchNormalization()(inputs)
    conv = tf.keras.layers.Conv2D(64, kernel_size=5, strides=1, padding='same', activation='relu')(bn)
    bn = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Conv2D(64, kernel_size=2, strides=1, padding='same', activation='relu')(bn)
    pool = tf.keras.layers.MaxPooling2D((2, 2))(conv)
    
    do=tf.keras.layers.Dropout(0.2)(pool)
    
    bn = tf.keras.layers.BatchNormalization()(do)
    conv = tf.keras.layers.Conv2D(128, kernel_size=5, strides=1, padding='same', activation='relu',kernel_regularizer = regularizers.l2(0.001))(bn)
    bn = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Conv2D(128, kernel_size=2, strides=1, padding='same', activation='relu',kernel_regularizer = regularizers.l2(0.001))(bn)
    pool = tf.keras.layers.MaxPooling2D((2, 2))(conv)

    do=tf.keras.layers.Dropout(0.2)(pool)
    
    bn = tf.keras.layers.BatchNormalization()(do)
    conv = tf.keras.layers.Conv2D(256, kernel_size=2, strides=1, padding='same', activation='relu',kernel_regularizer = regularizers.l2(0.001))(bn)
    bn = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Conv2D(256, kernel_size=2, strides=1, padding='same', activation='relu',kernel_regularizer = regularizers.l2(0.001))(bn)
    pool = tf.keras.layers.MaxPooling2D((2, 2))(conv)

    flatten = tf.keras.layers.Flatten()(pool)

    bn = tf.keras.layers.BatchNormalization()(flatten)
    dense = tf.keras.layers.Dense(1000, activation='relu')(bn)

    bn = tf.keras.layers.BatchNormalization()(dense)
    outputs = tf.keras.layers.Dense(10, activation='softmax')(bn)

    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
create_cnn_model().summary()
# Out:
# Model: "functional_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 84, 84, 1)]       0
# _________________________________________________________________
# batch_normalization_80 (Batc (None, 84, 84, 1)         4
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 84, 84, 64)        1664
# _________________________________________________________________
# batch_normalization_81 (Batc (None, 84, 84, 64)        256
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 84, 84, 64)        16448
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 42, 42, 64)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 42, 42, 64)        0
# _________________________________________________________________
# batch_normalization_82 (Batc (None, 42, 42, 64)        256
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 42, 42, 128)       204928
# _________________________________________________________________
# batch_normalization_83 (Batc (None, 42, 42, 128)       512
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 42, 42, 128)       65664
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_84 (Batc (None, 21, 21, 128)       512
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 21, 21, 256)       131328
# _________________________________________________________________
# batch_normalization_85 (Batc (None, 21, 21, 256)       1024
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 21, 21, 256)       262400
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 10, 10, 256)       0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 25600)             0
# _________________________________________________________________
# batch_normalization_86 (Batc (None, 25600)             102400
# _________________________________________________________________
# dense_20 (Dense)             (None, 1000)              25601000
# _________________________________________________________________
# batch_normalization_87 (Batc (None, 1000)              4000
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                10010
# =================================================================
# Total params: 26,402,406
# Trainable params: 26,347,924
# Non-trainable params: 54,482
# _________________________________________________________________

# %%
annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x)

# 이미지 증식 사용
datagen = ImageDataGenerator(
    rotation_range=10,  
    zoom_range = 0.1, 
    width_shift_range=0.1,
    height_shift_range=0.1)

model = create_cnn_model()
epochs=200

#model.fit(x_train, y_train, epochs=50)

history = model.fit(
  datagen.flow(x_train2, y_train, batch_size=16),
  epochs=epochs, 
  steps_per_epoch = x_train2.shape[0]//16,
  callbacks=[annealer], 
  verbose = 1
)
# Out:
# Epoch 1/200
# 128/128 [==============================] - 3s 23ms/step - loss: 3.7438 - accuracy: 0.3647
# Epoch 2/200
# 128/128 [==============================] - 3s 23ms/step - loss: 2.1847 - accuracy: 0.5361
# Epoch 3/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.9549 - accuracy: 0.5742
# Epoch 4/200
# 128/128 [==============================] - 3s 23ms/step - loss: 1.7010 - accuracy: 0.6504
# Epoch 5/200
# 128/128 [==============================] - 3s 23ms/step - loss: 1.6104 - accuracy: 0.6807
# Epoch 6/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.5147 - accuracy: 0.6963
# Epoch 7/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.3861 - accuracy: 0.7285
# Epoch 8/200
# 128/128 [==============================] - 3s 23ms/step - loss: 1.3307 - accuracy: 0.7441
# Epoch 9/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.1983 - accuracy: 0.7842
# Epoch 10/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.1326 - accuracy: 0.8032
# Epoch 11/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.0900 - accuracy: 0.8154
# Epoch 12/200
# 128/128 [==============================] - 3s 22ms/step - loss: 1.0352 - accuracy: 0.8228
# Epoch 13/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.9775 - accuracy: 0.8311
# Epoch 14/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.9565 - accuracy: 0.8291
# Epoch 15/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.9045 - accuracy: 0.8472
# Epoch 16/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.8580 - accuracy: 0.8569
# Epoch 17/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.8289 - accuracy: 0.8633
# Epoch 18/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.7839 - accuracy: 0.8716
# Epoch 19/200
# 128/128 [==============================] - 3s 24ms/step - loss: 0.7449 - accuracy: 0.8823
# Epoch 20/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.7354 - accuracy: 0.8760
# Epoch 21/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.6760 - accuracy: 0.8901
# Epoch 22/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.6621 - accuracy: 0.8931
# Epoch 23/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.6218 - accuracy: 0.9053
# Epoch 24/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.6037 - accuracy: 0.9053
# Epoch 25/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.5748 - accuracy: 0.9136
# Epoch 26/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.5566 - accuracy: 0.9180
# Epoch 27/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.5306 - accuracy: 0.9204
# Epoch 28/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.5321 - accuracy: 0.9175
# Epoch 29/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.4995 - accuracy: 0.9292
# Epoch 30/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.4805 - accuracy: 0.9312
# Epoch 31/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.4712 - accuracy: 0.9243
# Epoch 32/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.4352 - accuracy: 0.9463
# Epoch 33/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.4373 - accuracy: 0.9326
# Epoch 34/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.4087 - accuracy: 0.9434
# Epoch 35/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.4043 - accuracy: 0.9453
# Epoch 36/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.3868 - accuracy: 0.9561
# Epoch 37/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3840 - accuracy: 0.9463
# Epoch 38/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3631 - accuracy: 0.9492
# Epoch 39/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3607 - accuracy: 0.9561
# Epoch 40/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3509 - accuracy: 0.9575
# Epoch 41/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3361 - accuracy: 0.9570
# Epoch 42/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3356 - accuracy: 0.9585
# Epoch 43/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3132 - accuracy: 0.9653
# Epoch 44/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.3069 - accuracy: 0.9575
# Epoch 45/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2974 - accuracy: 0.9673
# Epoch 46/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2992 - accuracy: 0.9634
# Epoch 47/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2778 - accuracy: 0.9751
# Epoch 48/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2817 - accuracy: 0.9712
# Epoch 49/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2707 - accuracy: 0.9751
# Epoch 50/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2665 - accuracy: 0.9736
# Epoch 51/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2525 - accuracy: 0.9746
# Epoch 52/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2471 - accuracy: 0.9800
# Epoch 53/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2414 - accuracy: 0.9790
# Epoch 54/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2395 - accuracy: 0.9800
# Epoch 55/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2323 - accuracy: 0.9771
# Epoch 56/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2398 - accuracy: 0.9810
# Epoch 57/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2303 - accuracy: 0.9834
# Epoch 58/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2348 - accuracy: 0.9790
# Epoch 59/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2279 - accuracy: 0.9795
# Epoch 60/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2153 - accuracy: 0.9829
# Epoch 61/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2196 - accuracy: 0.9829
# Epoch 62/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2084 - accuracy: 0.9878
# Epoch 63/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2083 - accuracy: 0.9844
# Epoch 64/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2092 - accuracy: 0.9854
# Epoch 65/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2121 - accuracy: 0.9839
# Epoch 66/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.2090 - accuracy: 0.9790
# Epoch 67/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1958 - accuracy: 0.9883
# Epoch 68/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2003 - accuracy: 0.9844
# Epoch 69/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1941 - accuracy: 0.9849
# Epoch 70/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1920 - accuracy: 0.9878
# Epoch 71/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1852 - accuracy: 0.9893
# Epoch 72/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1833 - accuracy: 0.9897
# Epoch 73/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1913 - accuracy: 0.9854
# Epoch 74/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1876 - accuracy: 0.9878
# Epoch 75/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1756 - accuracy: 0.9922
# Epoch 76/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1895 - accuracy: 0.9858
# Epoch 77/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1789 - accuracy: 0.9893
# Epoch 78/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1847 - accuracy: 0.9844
# Epoch 79/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1757 - accuracy: 0.9888
# Epoch 80/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1796 - accuracy: 0.9893
# Epoch 81/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1776 - accuracy: 0.9888
# Epoch 82/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1720 - accuracy: 0.9932
# Epoch 83/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1718 - accuracy: 0.9932
# Epoch 84/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1753 - accuracy: 0.9902
# Epoch 85/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1666 - accuracy: 0.9917
# Epoch 86/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1734 - accuracy: 0.9893
# Epoch 87/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1658 - accuracy: 0.9917
# Epoch 88/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1766 - accuracy: 0.9873
# Epoch 89/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1720 - accuracy: 0.9917
# Epoch 90/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1705 - accuracy: 0.9917
# Epoch 91/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1645 - accuracy: 0.9937
# Epoch 92/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1595 - accuracy: 0.9937
# Epoch 93/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1689 - accuracy: 0.9917
# Epoch 94/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1635 - accuracy: 0.9907
# Epoch 95/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1666 - accuracy: 0.9897
# Epoch 96/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1593 - accuracy: 0.9956
# Epoch 97/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1644 - accuracy: 0.9888
# Epoch 98/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1618 - accuracy: 0.9912
# Epoch 99/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1688 - accuracy: 0.9912
# Epoch 100/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1637 - accuracy: 0.9912
# Epoch 101/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1614 - accuracy: 0.9917
# Epoch 102/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1548 - accuracy: 0.9961
# Epoch 103/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1609 - accuracy: 0.9912
# Epoch 104/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1573 - accuracy: 0.9927
# Epoch 105/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1550 - accuracy: 0.9956
# Epoch 106/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1551 - accuracy: 0.9946
# Epoch 107/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1551 - accuracy: 0.9951
# Epoch 108/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1559 - accuracy: 0.9946
# Epoch 109/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1591 - accuracy: 0.9912
# Epoch 110/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1603 - accuracy: 0.9897
# Epoch 111/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1584 - accuracy: 0.9922
# Epoch 112/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1569 - accuracy: 0.9932
# Epoch 113/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1492 - accuracy: 0.9976
# Epoch 114/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1609 - accuracy: 0.9927
# Epoch 115/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1542 - accuracy: 0.9956
# Epoch 116/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1526 - accuracy: 0.9951
# Epoch 117/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1597 - accuracy: 0.9912
# Epoch 118/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1610 - accuracy: 0.9937
# Epoch 119/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1591 - accuracy: 0.9932
# Epoch 120/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1533 - accuracy: 0.9956
# Epoch 121/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1583 - accuracy: 0.9937
# Epoch 122/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1586 - accuracy: 0.9922
# Epoch 123/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1578 - accuracy: 0.9917
# Epoch 124/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1487 - accuracy: 0.9966
# Epoch 125/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1528 - accuracy: 0.9951
# Epoch 126/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1562 - accuracy: 0.9927
# Epoch 127/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1545 - accuracy: 0.9912
# Epoch 128/200
# 128/128 [==============================] - 3s 24ms/step - loss: 0.1554 - accuracy: 0.9946
# Epoch 129/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1617 - accuracy: 0.9907
# Epoch 130/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1530 - accuracy: 0.9951
# Epoch 131/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1530 - accuracy: 0.9932
# Epoch 132/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1603 - accuracy: 0.9907
# Epoch 133/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1599 - accuracy: 0.9922
# Epoch 134/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1504 - accuracy: 0.9951
# Epoch 135/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1533 - accuracy: 0.9946
# Epoch 136/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1487 - accuracy: 0.9951
# Epoch 137/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1507 - accuracy: 0.9941
# Epoch 138/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1550 - accuracy: 0.9932
# Epoch 139/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1531 - accuracy: 0.9951
# Epoch 140/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1476 - accuracy: 0.9951
# Epoch 141/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1548 - accuracy: 0.9951
# Epoch 142/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1495 - accuracy: 0.9966
# Epoch 143/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1488 - accuracy: 0.9946
# Epoch 144/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1469 - accuracy: 0.9946
# Epoch 145/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1516 - accuracy: 0.9941
# Epoch 146/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1522 - accuracy: 0.9941
# Epoch 147/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1520 - accuracy: 0.9941
# Epoch 148/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1549 - accuracy: 0.9946
# Epoch 149/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1509 - accuracy: 0.9946
# Epoch 150/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1494 - accuracy: 0.9927
# Epoch 151/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1563 - accuracy: 0.9917
# Epoch 152/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1566 - accuracy: 0.9932
# Epoch 153/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1542 - accuracy: 0.9917
# Epoch 154/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1555 - accuracy: 0.9927
# Epoch 155/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1508 - accuracy: 0.9937
# Epoch 156/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1498 - accuracy: 0.9937
# Epoch 157/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1500 - accuracy: 0.9961
# Epoch 158/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1494 - accuracy: 0.9941
# Epoch 159/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1499 - accuracy: 0.9937
# Epoch 160/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1545 - accuracy: 0.9932
# Epoch 161/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1508 - accuracy: 0.9951
# Epoch 162/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1488 - accuracy: 0.9941
# Epoch 163/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1563 - accuracy: 0.9941
# Epoch 164/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1541 - accuracy: 0.9941
# Epoch 165/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1542 - accuracy: 0.9927
# Epoch 166/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1588 - accuracy: 0.9897
# Epoch 167/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1517 - accuracy: 0.9927
# Epoch 168/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1479 - accuracy: 0.9961
# Epoch 169/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1588 - accuracy: 0.9922
# Epoch 170/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1541 - accuracy: 0.9937
# Epoch 171/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1517 - accuracy: 0.9961
# Epoch 172/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1516 - accuracy: 0.9922
# Epoch 173/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1508 - accuracy: 0.9946
# Epoch 174/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1488 - accuracy: 0.9951
# Epoch 175/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1527 - accuracy: 0.9946
# Epoch 176/200
# 128/128 [==============================] - 3s 24ms/step - loss: 0.1524 - accuracy: 0.9941
# Epoch 177/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1570 - accuracy: 0.9922
# Epoch 178/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1540 - accuracy: 0.9932
# Epoch 179/200
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1555 - accuracy: 0.9917
# Epoch 180/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1511 - accuracy: 0.9951
# Epoch 181/200
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1561 - accuracy: 0.9951
# Epoch 182/200
#  64/128 [==============>...............] - ETA: 1s - loss: 0.1551 - accuracy: 0.9922

# %% [markdown]
# ## Predict

# %%
x_test = test.drop(['id', 'letter'], axis=1).values
x_test = x_test.reshape(-1, 28, 28, 1)
x_test = x_test/255

# %%
x_test1 = np.repeat(x_test, 3, axis=1)

# %%
x_test2 = np.repeat(x_test1, 3, axis=2)

# %%
submission = pd.read_csv('data/submission.csv')
submission['digit'] = np.argmax(model.predict(x_test2), axis=1)
submission.head(50)

# %%
submission.to_csv('3배_do0.2.csv', index=False)
